# %%
import pandas as pd

# %%
#

series = pd.Series([5, 10, 15, 20, 25])
series
# Out:
# 0     5
# 1    10
# 2    15
# 3    20
# 4    25
# dtype: int64

# %%
type(series)
# Out:
# pandas.core.series.Series

# %%
#Veremos el elemento 3 de la serie, recuerda que la serie es parecido al diccionario
#en la serie podemos seleccionar la etiqueta y esta nos muestra el valor asociado a la etiqueta: Igual que un diccionario
series[3]
# Out:
# 20

# %%
#Aquí otro ejemplo, pero a quí nos estamos dando cuenta que la "etiqueta"  para cada elemento es un número

cad = pd.Series(['p', 'l', 'a', 't', 'z', 'i'])
cad
# Out:
# 0    p
# 1    l
# 2    a
# 3    t
# 4    z
# 5    i
# dtype: object

# %%
#Ahora veremos la estructura con dataframe, una estructura muy usada de pandas en la actualidad

#son estructuras que nos permiten crear estructuras de datos como si estuvieramos  usando SQL
lst= ['Hola', 'mundo', 'robotico']
df = pd.DataFrame(lst) # Ahora le decimos que creamos el DataFrame  le asignamos a la estreuctura anterior:la lista
print(df)
df
# Out:
#           0
# 0      Hola
# 1     mundo
# 2  robotico
#           0
# 0      Hola
# 1     mundo
# 2  robotico

# %%
#Veremos Otra estructura

data = {'Nombre': ['Juan', 'Ana', 'Jose', 'Arturo'],
        'Edad': [25, 18, 23, 27],
        'Pais': ['MX', 'CL', 'BR', 'PE']}

df = pd.DataFrame(data)
df
# Out:
#    Nombre  Edad Pais
# 0    Juan    25   MX
# 1     Ana    18   CL
# 2    Jose    23   BR
# 3  Arturo    27   PE

# %%
#Si queremos solo imprimir 2 estructuras de todo lo que hay en df, entonces lo hacemos de esta manera
print(df[['Nombre', 'Pais']])
# Out:
#    Nombre Pais
# 0    Juan   MX
# 1     Ana   CL
# 2    Jose   BR
# 3  Arturo   PE

# %%
data = pd.read_csv('canciones-2018.csv')
data.head(5)
# Out:
#                       id  ... time_signature
# 0  6DCZcSspjsKoFjzjrWoCd  ...            4.0
# 1  3ee8Jmje8o58CHK66QrVC  ...            4.0
# 2  0e7ipj03S05BNilyu5bRz  ...            4.0
# 3  3swc6WTsr7rl9DqQKQA55  ...            4.0
# 4  2G7V7zsVDxg1yRsu7Ew9R  ...            4.0
#
# [5 rows x 16 columns]

# %%
#A artista le estamos entregando los datos de la colmna artistists
artista = data.artists

artista[5]
# Out:
# 'Post Malone'

# %%
#Otro método como ".iloc" nos permite describir qué estoy viendo, qué tipo de datos estoy trabajando
#En resumen, ".iloc" nos menciona la información de cada una de las columnas del elemento
info = data.iloc[15]
info
# Out:
# id                     3GCdLUSnKSMJhs4Tj6CV3
# name                All The Stars (with SZA)
# artists                       Kendrick Lamar
# danceability                           0.698
# energy                                 0.633
# key                                        8
# loudness                              -4.946
# mode                                       1
# speechiness                           0.0597
# acousticness                          0.0605
# instrumentalness                    0.000194
# liveness                              0.0926
# valence                                0.552
# tempo                                 96.924
# duration_ms                           232187
# time_signature                             4
# Name: 15, dtype: object

# %%
#Si queremos ver la información que está en el final, hacemos lo siguiente
data.tail()
# Out:
#                        id  ... time_signature
# 95  630sXRhIcfwr2e4RdNtjK  ...            4.0
# 96  2xmrfQpmS2iJExTlklLoA  ...            4.0
# 97  5WvAo7DNuPRmk4APhdPzi  ...            5.0
# 98  1j4kHkkpqZRBwE0A4CN4Y  ...            4.0
# 99  3EPXxR3ImUwfayaurPi3c  ...            4.0
#
# [5 rows x 16 columns]

# %%
#Si queremos ver la amplitud o la "forma" de estos datos, hacemos..

data.shape
# Out:
# (100, 16)

# %%
#Si queremos ver la descripción o los nombres de cada columna, hacemos ...

data.columns
# Out:
# Index(['id', 'name', 'artists', 'danceability', 'energy', 'key', 'loudness',
#        'mode', 'speechiness', 'acousticness', 'instrumentalness', 'liveness',
#        'valence', 'tempo', 'duration_ms', 'time_signature'],
#       dtype='object')

# %%
#Si queremos ver la descripción de una columna en particular, hacemos
#esto nos mostrará la media, desv. estandar, máx, min, etc

data['tempo'].describe()

# %%
#Para ordenar los datos
data.sort_index(axis = 0, ascending =False) # con False estamos indicando que sea de orden descendente
                                            # con axis =0 indicamos de dónde empieza  a ordenar desde la posición '0'

# %%
lst = data[['artists', 'energy', 'instrumentalness' ]]
lst.sort_index(axis = 0, ascending = True).head(5)
# Out:
#         artists  energy  instrumentalness
# 0         Drake   0.449          0.000083
# 1  XXXTENTACION   0.613          0.003720
# 2   Post Malone   0.535          0.000066
# 3   Post Malone   0.559          0.000000
# 4         Drake   0.626          0.000060
