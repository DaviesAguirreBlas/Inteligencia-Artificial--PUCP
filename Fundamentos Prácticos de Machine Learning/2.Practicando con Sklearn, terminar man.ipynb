# %%
import pandas as pd
from sklearn.model_selection import train_test_split
from sklearn.linear_model import LinearRegression
import matplotlib.pyplot as plt

# %%
dataset = pd.read_csv('Salarios2.csv')
dataset.head(5)
# Out:
#    Aexperiencia  Salario     Pais
# 0          10.0    42500    Chile
# 1           8.0    36302    Chile
# 2           5.4    35000   España
# 3           2.5    18103     Peru
# 4           1.0    15000  Colomia

# %%
x = dataset.iloc[:, :-1].values
y_numeros = dataset[['Aexperiencia', 'Pais']] 
#y = y_numeros( pd.factorize(dataset['Pais'])[0]

print(y_numeros)
# Out:
#     Aexperiencia       Pais
# 0           10.0      Chile
# 1            8.0      Chile
# 2            5.4     España
# 3            2.5       Peru
# 4            1.0    Colomia
# 5            8.0   Colombia
# 6            4.0     Mexico
# 7            6.0     Mexico
# 8            2.0      Chile
# 9           10.0      Chile
# 10           4.0     España
# 11           7.0     España
# 12           3.0     Mexico
# 13           5.0       Peru
# 14           2.0       Peru
# 15           5.0     España
# 16           3.0       Peru
# 17           2.0      Chile
# 18           3.0       Peru
# 19           2.0   Colombia
# 20           5.0   Colombia
# 21           3.4     España
# 22           5.3      Chile
# 23           2.1  Argentina
# 24           9.2     España
# 25          10.0     Mexico
# 26           3.2  Argentina
# 27          10.0   Colombia
# 28           4.0      Chile
# 29           1.0       Peru

# %%
X_train, X_test, Y_train, Y_test = train_test_split(x, y, test_size = 0.2, random_state =0)

# %%
regressor = LinearRegression()
regressor.fit(X_train, Y_train)
# Out:
# LinearRegression(copy_X=True, fit_intercept=True, n_jobs=None, normalize=False)

# %%
grafico = plt
grafico.scatter(X_train, Y_train, color = 'blue')
grafico.plot(X_train, regressor.predict(X_train), colors = 'green')
grafico.xlabel('')
